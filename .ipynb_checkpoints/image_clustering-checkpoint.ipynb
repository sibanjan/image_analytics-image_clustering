# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import ndimage
from sklearn import cluster
image = ndimage.imread("sibanjan.jpg")
plt.figure(figsize = (15,8))
plt.imshow(image)
# Out:
# /Users/sibanjan/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """

# %%
image.shape
# Out:
# (852, 728, 3)

# %%
x, y, z = image.shape
image_2d = image.reshape(x*y, z)
image_2d.shape
# Out:
# (620256, 3)

# %%
kmeans_cluster = cluster.KMeans(n_clusters=5)
kmeans_cluster.fit(image_2d)
cluster_centers = kmeans_cluster.cluster_centers_
cluster_centers
# Out:
# array([[198.27852842, 194.93925502, 187.73300703],
#        [ 33.01923307,  33.46835011,  35.40320338],
#        [152.56446636, 148.55823882, 145.11938006],
#        [220.66898734, 218.24131335, 211.81965861],
#        [ 88.21381665,  86.93226294,  89.74776727]])

# %%
cluster_labels = kmeans_cluster.labels_
cluster_labels
# Out:
# array([3, 3, 3, ..., 4, 4, 2], dtype=int32)

# %%
plt.figure(figsize = (15,8))
plt.imshow(cluster_centers[cluster_labels].reshape(x, y, z))
